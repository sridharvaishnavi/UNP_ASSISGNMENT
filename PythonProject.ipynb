# %% [markdown]
# <a href="https://colab.research.google.com/github/sridharvaishnavi/UNP_ASSISGNMENT/blob/main/PythonProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px

# %%
null_values=["?",]
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/hepatitis/hepatitis.data', index_col=False, na_values=null_values,
                    names=["class","AGE","SEX","STEROID","ANTIVIRALS","FATIGUE","MALAISE","ANOREXIA","LIVER BIG","SPLEEN PALPABLE","SPIDERS","ASCITES","VARICES","BILIRUBIN","ALK PHOSPHATE","SGOT","ALBUMIN","PROTINE","HISTOLOGY" ])

# %%
data
# Out:
#      class  AGE  SEX  STEROID  ...        SGOT  ALBUMIN  PROTINE  HISTOLOGY
# 0        2   30    2      1.0  ...   85.000000     18.0      4.0      100.0
# 1        2   50    1      1.0  ...  135.000000     42.0      3.5      100.0
# 2        2   78    1      2.0  ...   96.000000     32.0      4.0      100.0
# 3        2   31    1      2.0  ...   46.000000     52.0      4.0       80.0
# 4        2   34    1      2.0  ...  105.325397    200.0      4.0      100.0
# ..     ...  ...  ...      ...  ...         ...      ...      ...        ...
# 150      1   46    1      2.0  ...  105.325397    242.0      3.3       50.0
# 151      2   44    1      2.0  ...  126.000000    142.0      4.3      100.0
# 152      2   61    1      1.0  ...   75.000000     20.0      4.1      100.0
# 153      2   53    2      1.0  ...   81.000000     19.0      4.1       48.0
# 154      1   43    1      2.0  ...  100.000000     19.0      3.1       42.0
#
# [155 rows x 19 columns]

# %%
data.shape
# Out:
# (155, 19)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   class            155 non-null    int64
#  1   AGE              155 non-null    int64
#  2   SEX              155 non-null    int64
#  3   STEROID          155 non-null    float64
#  4   ANTIVIRALS       155 non-null    int64
#  5   FATIGUE          155 non-null    float64
#  6   MALAISE          155 non-null    float64
#  7   ANOREXIA         155 non-null    float64
#  8   LIVER BIG        155 non-null    float64
#  9   SPLEEN PALPABLE  155 non-null    float64
#  10  SPIDERS          155 non-null    float64
#  11  ASCITES          155 non-null    float64
#  12  VARICES          155 non-null    float64
#  13  BILIRUBIN        155 non-null    float64
#  14  ALK PHOSPHATE    155 non-null    float64
#  15  SGOT             155 non-null    float64
#  16  ALBUMIN          155 non-null    float64
#  17  PROTINE          155 non-null    float64
#  18  HISTOLOGY        155 non-null    float64
# dtypes: float64(15), int64(4)
# memory usage: 23.1 KB

# %%
data.isnull().sum()
# Out:
# class              0
# AGE                0
# SEX                0
# STEROID            0
# ANTIVIRALS         0
# FATIGUE            0
# MALAISE            0
# ANOREXIA           0
# LIVER BIG          0
# SPLEEN PALPABLE    0
# SPIDERS            0
# ASCITES            0
# VARICES            0
# BILIRUBIN          0
# ALK PHOSPHATE      0
# SGOT               0
# ALBUMIN            0
# PROTINE            0
# HISTOLOGY          0
# dtype: int64

# %%
#replacing missing values
continuous_features = ["AGE","ALK PHOSPHATE",	"SGOT",	"ALBUMIN"	,"PROTINE"]
for column in continuous_features:
    data[column]=data[column].fillna(data[column].mean())

for column in data.columns.drop(continuous_features):
    data[column]=data[column].fillna(data[column].mode().sample(1,random_state=1).values[0])

# %%
#describing data
data.describe()
# Out:
#             class         AGE         SEX  ...     ALBUMIN     PROTINE   HISTOLOGY
# count  155.000000  155.000000  155.000000  ...  155.000000  155.000000  155.000000
# mean     1.793548   41.200000    1.103226  ...   85.894040    3.817266   78.341935
# std      0.406070   12.565878    0.305240  ...   88.478932    0.616750   25.594348
# min      1.000000    7.000000    1.000000  ...   14.000000    2.100000    0.000000
# 25%      2.000000   32.000000    1.000000  ...   32.500000    3.500000   57.000000
# 50%      2.000000   39.000000    1.000000  ...   59.000000    3.900000  100.000000
# 75%      2.000000   50.000000    1.000000  ...   99.000000    4.200000  100.000000
# max      2.000000   78.000000    2.000000  ...  648.000000    6.400000  100.000000
#
# [8 rows x 19 columns]

# %%
plt.figure(figsize=(12,6))
sns.countplot(data['class'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.figure(figsize=(14,5))
sns.pairplot(data)
plt.show()

# %%
plt.figure(figsize=(14,5))
sns.scatterplot(data['ALK PHOSPHATE'],data['AGE'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.figure(figsize=(14,5))
sns.scatterplot(data['HISTOLOGY'],data['ALK PHOSPHATE'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.figure(figsize=(14,5))
sns.scatterplot(data['HISTOLOGY'],data['SGOT'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.figure(figsize=(14,5))
sns.scatterplot(data['HISTOLOGY'],data['PROTINE'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.figure(figsize=(12,6))
sns.barplot(data['class'],data['VARICES'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.figure(figsize=(12,6))
sns.barplot(data['class'],data['ALK PHOSPHATE'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
#heat map
corr=data.corr()
plt.subplots(figsize =(16,8))
sns.heatmap(corr, annot=True, cmap='coolwarm')

# %%
data.corr()['class'].sort_values()
# Out:
# ALK PHOSPHATE     -0.450470
# AGE               -0.219647
# SGOT              -0.141005
# ANTIVIRALS        -0.130196
# LIVER BIG         -0.093665
# ALBUMIN           -0.075579
# SPLEEN PALPABLE    0.020057
# ANOREXIA           0.133638
# STEROID            0.137413
# SEX                0.173051
# HISTOLOGY          0.202396
# SPIDERS            0.234261
# FATIGUE            0.306049
# MALAISE            0.339530
# BILIRUBIN          0.362385
# ASCITES            0.389137
# PROTINE            0.465827
# VARICES            0.469334
# class              1.000000
# Name: class, dtype: float64

# %%
#correlation
data.corr()
# Out:
#                     class       AGE       SEX  ...   ALBUMIN   PROTINE  HISTOLOGY
# class            1.000000 -0.219647  0.173051  ... -0.075579  0.465827   0.202396
# AGE             -0.219647  1.000000  0.008126  ...  0.081052 -0.246169  -0.115622
# SEX              0.173051  0.008126  1.000000  ... -0.017625  0.005459  -0.066886
# STEROID          0.137413 -0.090466 -0.048985  ... -0.044154  0.216697   0.033887
# ANTIVIRALS      -0.130196 -0.013100 -0.089249  ...  0.107876 -0.165443   0.204972
# FATIGUE          0.306049 -0.278701 -0.070059  ... -0.199808  0.311757   0.173314
# MALAISE          0.339530 -0.117876 -0.030523  ... -0.202801  0.290698   0.181620
# ANOREXIA         0.133638  0.088317  0.015886  ... -0.234824  0.155587  -0.021279
# LIVER BIG       -0.093665 -0.089629 -0.081830  ...  0.050390 -0.057149  -0.079382
# SPLEEN PALPABLE  0.020057 -0.092001 -0.078642  ... -0.092868  0.174551   0.135257
# SPIDERS          0.234261 -0.061277 -0.048478  ...  0.017947  0.216003   0.101301
# ASCITES          0.389137 -0.156545 -0.033192  ... -0.078187  0.290618   0.126718
# VARICES          0.469334 -0.055314  0.130587  ...  0.034670  0.527344   0.295588
# BILIRUBIN        0.362385 -0.039229  0.056792  ... -0.012309  0.333906   0.244029
# ALK PHOSPHATE   -0.450470  0.122884 -0.056218  ...  0.232610 -0.370712  -0.091258
# SGOT            -0.141005  0.008076  0.073253  ...  0.193969 -0.338158  -0.084571
# ALBUMIN         -0.075579  0.081052 -0.017625  ...  1.000000 -0.115455  -0.094834
# PROTINE          0.465827 -0.246169  0.005459  ... -0.115455  1.000000   0.224540
# HISTOLOGY        0.202396 -0.115622 -0.066886  ... -0.094834  0.224540   1.000000
#
# [19 rows x 19 columns]

# %%
X=data.iloc[:,1:19]
y=data.iloc[:,0]

# %%
X.head()
# Out:
#    AGE  SEX  STEROID  ANTIVIRALS  ...        SGOT  ALBUMIN  PROTINE  HISTOLOGY
# 0   30    2      1.0           2  ...   85.000000     18.0      4.0      100.0
# 1   50    1      1.0           2  ...  135.000000     42.0      3.5      100.0
# 2   78    1      2.0           2  ...   96.000000     32.0      4.0      100.0
# 3   31    1      2.0           1  ...   46.000000     52.0      4.0       80.0
# 4   34    1      2.0           2  ...  105.325397    200.0      4.0      100.0
#
# [5 rows x 18 columns]

# %%
y.head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: class, dtype: int64

# %%
#splitting data into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
#logistic regression 
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state= 45, max_iter=1000)
classifier.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=45)

# %%
#test set results
y_pred = classifier.predict(X_test)

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)

# %%
print(cm)
# Out:
# [[ 4  6]
#  [ 0 29]]

# %%
#accuracy 
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)*100
# Out:
# 84.61538461538461

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      0.40      0.57        10
#            2       0.83      1.00      0.91        29
#
#     accuracy                           0.85        39
#    macro avg       0.91      0.70      0.74        39
# weighted avg       0.87      0.85      0.82        39
